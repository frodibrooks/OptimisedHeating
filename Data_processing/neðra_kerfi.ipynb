# %% [markdown]
# <img src="þrýstisvæðið.png" alt="Title" width="900">

# %% [markdown]
# # Initial data processing
# Neðra kerfi ljós gult

# %%
#import matplotlib.pyplot as plt
#import pandas as pd

# %%
# Replace 'your_file.xlsx' with the actual file path
df = pd.read_excel("/Users/frodibrooks/Desktop/DTU/Thesis/Úrvinnsla/Vatnsenda_NeðraKerfi_Supply.xlsx")

# Display the first few rows
df.head()
# Out:
#                   mpoint_id                                       mpoint_name  \
# 0  H-KOP-VE-XR213|ACT_VALUE  Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi
# 1  H-KOP-VE-XR213|OUT_VALUE  Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi
# 2   H-KOP-VE-XR213|PV_VALUE  Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi
# 3      H-KOP-VE-TS213|VALUE       Vatnsendi - Hiti á framrennsli neðra kerfis
# 4      H-KOP-VE-ÞS213|VALUE           Vatnsendi - Framþrýstingur neðra kerfis
#
#             start_time aggregate_name  aggregate_id  value  flag  \
# 0  2024-01-23 20:00:00        Average             4  70.49     0
# 1  2024-01-23 20:00:00        Average             4  71.14     0
# 2  2024-01-23 20:00:00        Average             4   5.38     0
# 3  2024-01-23 20:00:00        Average             4  80.03     0
# 4  2024-01-23 20:00:00        Average             4   5.66     0
#
#                                  quality_description  event_time
# ...

# %%
df = df.drop(columns=["aggregate_name", "aggregate_id", "flag", "event_time", "quality_description"])
df.head()
# Out:
#                   mpoint_id                                       mpoint_name  \
# 0  H-KOP-VE-XR213|ACT_VALUE  Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi
# 1  H-KOP-VE-XR213|OUT_VALUE  Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi
# 2   H-KOP-VE-XR213|PV_VALUE  Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi
# 3      H-KOP-VE-TS213|VALUE       Vatnsendi - Hiti á framrennsli neðra kerfis
# 4      H-KOP-VE-ÞS213|VALUE           Vatnsendi - Framþrýstingur neðra kerfis
#
#             start_time  value
# 0  2024-01-23 20:00:00  70.49
# 1  2024-01-23 20:00:00  71.14
# 2  2024-01-23 20:00:00   5.38
# 3  2024-01-23 20:00:00  80.03
# 4  2024-01-23 20:00:00   5.66

# %%
# Handle missing time information by converting 'start_time' to datetime with error handling
df['start_time'] = pd.to_datetime(df['start_time'], errors='coerce')


df_H_KOP_VE_XR213_ACT_VALUE = df[df['mpoint_id'] == 'H-KOP-VE-XR213|ACT_VALUE'].copy()

# Set 'start_time' as index and rename 'value' column
df_H_KOP_VE_XR213_ACT_VALUE.set_index('start_time', inplace=True)
df_H_KOP_VE_XR213_ACT_VALUE.rename(columns={'value': 'value'}, inplace=True)

# %%
# Handle missing time information by converting 'start_time' to datetime with error handling
df['start_time'] = pd.to_datetime(df['start_time'], errors='coerce')


df_H_KOP_VE_XR213_OUT_VALUE = df[df['mpoint_id'] == 'H-KOP-VE-XR213|OUT_VALUE'].copy()

# Set 'start_time' as index and rename 'value' column
df_H_KOP_VE_XR213_OUT_VALUE.set_index('start_time', inplace=True)
df_H_KOP_VE_XR213_OUT_VALUE.rename(columns={'value': 'value'}, inplace=True)

# %%
# Handle missing time information by converting 'start_time' to datetime with error handling
df['start_time'] = pd.to_datetime(df['start_time'], errors='coerce')


df_H_KOP_VE_XR213_PV_VALUE = df[df['mpoint_id'] == 'H-KOP-VE-XR213|PV_VALUE'].copy()

# Set 'start_time' as index and rename 'value' column
df_H_KOP_VE_XR213_PV_VALUE.set_index('start_time', inplace=True)
df_H_KOP_VE_XR213_PV_VALUE.rename(columns={'value': 'value'}, inplace=True)

# %%
# Handle missing time information by converting 'start_time' to datetime with error handling
df['start_time'] = pd.to_datetime(df['start_time'], errors='coerce')


df_H_KOP_VE_TS213_VALUE = df[df['mpoint_id'] == 'H-KOP-VE-TS213|VALUE'].copy()

# Set 'start_time' as index and rename 'value' column
df_H_KOP_VE_TS213_VALUE.set_index('start_time', inplace=True)
df_H_KOP_VE_TS213_VALUE.rename(columns={'value': 'value'}, inplace=True)

# %%
# Handle missing time information by converting 'start_time' to datetime with error handling
df['start_time'] = pd.to_datetime(df['start_time'], errors='coerce')


df_H_KOP_VE_ÞS213_VALUE = df[df['mpoint_id'] == 'H-KOP-VE-ÞS213|VALUE'].copy()

# Set 'start_time' as index and rename 'value' column
df_H_KOP_VE_ÞS213_VALUE.set_index('start_time', inplace=True)
df_H_KOP_VE_ÞS213_VALUE.rename(columns={'value': 'value'}, inplace=True)

# %%
# Plot the dataframe
plt.figure(figsize=(10, 6))
plt.scatter(df_H_KOP_VE_XR213_ACT_VALUE.index, df_H_KOP_VE_XR213_ACT_VALUE['value'], marker='o', color='b',alpha = 0.1)

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi Óskgildi')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mg/pzsnhp7x6vsfphvx57vfh73c0000gn/T/ipykernel_10248/3954187336.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot the dataframe
plt.figure(figsize=(10, 6))
plt.scatter(df_H_KOP_VE_XR213_OUT_VALUE.index, df_H_KOP_VE_XR213_OUT_VALUE['value'], marker='o', color='b',alpha = 0.1)

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi Raungildi')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mg/pzsnhp7x6vsfphvx57vfh73c0000gn/T/ipykernel_10248/2784150361.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot the dataframe
plt.figure(figsize=(10, 6))
plt.scatter(df_H_KOP_VE_XR213_PV_VALUE.index, df_H_KOP_VE_XR213_PV_VALUE['value'], marker='o', color='b',alpha = 0.1)

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Vatnsendi - Stjórnloki - þrýstingur- neðra kerfi Raungildi PV')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mg/pzsnhp7x6vsfphvx57vfh73c0000gn/T/ipykernel_10248/4072959932.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot the dataframe
plt.figure(figsize=(10, 6))
plt.scatter(df_H_KOP_VE_TS213_VALUE.index, df_H_KOP_VE_TS213_VALUE['value'], marker='o', color='b',alpha = 0.1)

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Vatnsendi - Hiti á framrennsli neðra kerfis')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mg/pzsnhp7x6vsfphvx57vfh73c0000gn/T/ipykernel_10248/3202958185.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot the dataframe
plt.figure(figsize=(10, 6))
plt.scatter(df_H_KOP_VE_ÞS213_VALUE.index, df_H_KOP_VE_ÞS213_VALUE['value'], marker='o', color='b',alpha = 0.1)

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Vatnsendi - Framþrýstingur neðra kerfis')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mg/pzsnhp7x6vsfphvx57vfh73c0000gn/T/ipykernel_10248/245289937.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
